# %%
import pandas as pd
import seaborn as sns
import os

# %%
n=int(input(""))

# %%
files = [f for f in os.listdir('.') if os.path.isfile(f)] #.remove('Plotter.ipynb')
files.remove('Plotter.ipynb')

# %%
#preparing df names
dfs=[]
for file in files:
    dfs.append('df_'+file.split('.')[0])
dfs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-1a041125736b> in <module>()
#       2 dfs={}
#       3 for file in files:
# ----> 4     dfs.append('df_'+file.split('.')[0])
#       5 dfs
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
for i in range(len(files)):
    setattr(dfs,dfs[i],pd.read_csv(files[i]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-16e90b299c2e> in <module>()
#       1 for i in range(len(files)):
# ----> 2     setattr(dfs,dfs[i],pd.read_csv(files[i]))
#       3
#
# AttributeError: 'list' object has no attribute 'df_500_dec_nz'

# %%
df_500_dec_nz=pd.read_csv('500_dec_nz.csv')
df_500_dec_nz
# Out:
#      avg_wait_time  avg_turnaround_time  context_switches
# 0         0.000000          1997.000000                 1
# 1      1497.500000          3493.500000                 4
# 2      1330.666667          3325.000000                 3
# 3      2928.000000          4920.750000                 6
# 4      3910.600000          5901.800000                 6
# 5      4880.833333          6870.833333                 7
# 6      5603.714286          7592.571429                 8
# 7      6265.250000          8253.125000                 9
# 8      6720.333333          8707.222222                10
# 9      7117.500000          9103.500000                11
# 10     7473.909091          9458.909091                12
# 11     7777.916667          9762.000000                13
# 12     8042.461538         10025.692308                14
# 13     8337.928571         10320.357143                15
# 14     8558.733333         10540.400000                16
# ...
